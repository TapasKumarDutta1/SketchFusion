# %%
from google.colab import drive
drive.mount('/content/drive',force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# !unzip /content/drive/MyDrive/PSC6K.zip
# Out:
# Archive:  /content/drive/MyDrive/PSC6K.zip
#   inflating: alignment_dataset.py
#   inflating: dataset_demo.ipynb
#   inflating: examples.png
#   inflating: photo_sketch_dataset.py
#   inflating: README.md
#   inflating: test_pairs_ps.csv
#   inflating: test_pairs_st.csv
#   inflating: train_pairs_ps.csv
#   inflating: train_pairs_st.csv

# %%
# !unzip /content/drive/MyDrive/subset.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: sketch/jack-o-lantern/n03590841_21-5.png
#   inflating: sketch/jack-o-lantern/n03590841_21-2.png
#   inflating: sketch/jack-o-lantern/n03590841_5428-4.png
#   inflating: sketch/jack-o-lantern/n03590841_10464-4.png
#   inflating: sketch/jack-o-lantern/n03590841_6046-4.png
#   inflating: sketch/jack-o-lantern/n03590841_6317-5.png
#   inflating: sketch/jack-o-lantern/n03590841_6317-4.png
#   inflating: sketch/jack-o-lantern/n03590841_6046-1.png
#   inflating: sketch/jack-o-lantern/n03590841_6317-2.png
#   inflating: sketch/jack-o-lantern/n03590841_5428-2.png
#   inflating: sketch/jack-o-lantern/n03590841_5996-5.png
#   inflating: sketch/jack-o-lantern/n03590841_5428-1.png
#   inflating: sketch/jack-o-lantern/n03590841_5996-4.png
#   inflating: sketch/jack-o-lantern/n03590841_6090-2.png
#   inflating: sketch/jack-o-lantern/n03590841_11564-1.png
#   inflating: sketch/jack-o-lantern/n03590841_5996-1.png
# ...

# %%
pip install torch==2.3.0
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 779.1/779.1 MB 1.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 2.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 89.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 70.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 59.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 1.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 17.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 37.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 18.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 5.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 176.2/176.2 MB 12.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 9.8 MB/s eta 0:00:00
# ...

# %%
# !python --version
# Out:
# Python 3.10.12

# %%
# !pip install -U torch torchvision -f https://download.pytorch.org/whl/torch_stable.html
# !pip install -U 'git+https://github.com/cocodataset/cocoapi.git#subdirectory=PythonAPI'
# !pip install detectron2 -f https://dl.fbaipublicfiles.com/detectron2/wheels/cpu/index.html
# Out:
# Looking in links: https://download.pytorch.org/whl/torch_stable.html
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 906.4/906.4 MB 1.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 2.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 61.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 50.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 50.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 10.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 38.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 18.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 3.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.7/188.7 MB 12.0 MB/s eta 0:00:00
# ...

# %%
cd src/SD_CLIP
# Out:
# /content/cleaned/src/geoaware_necessary_clone

# %%
# !pip install -e .
# Out:
# Obtaining file:///content/cleaned/src/geoaware_necessary_clone
#   Preparing metadata (setup.py) ... done
# Processing //content/cleaned/src/geoaware_necessary_clone/third_party/Mask2Former (from geo-aware==0.0.0)
#   Preparing metadata (setup.py) ... done
# Processing //content/cleaned/src/geoaware_necessary_clone/third_party/ODISE (from geo-aware==0.0.0)
#   Preparing metadata (setup.py) ... done
# ...
#      | 1.3 MB 6.6 MB/s 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      / 650.2 kB 27.4 MB/s 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      - 4.5 MB 25.1 MB/s 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 112.4/112.4 kB 4.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100.3/100.3 kB 9.2 MB/s eta 0:00:00
# ...

# %%
pip install torchvision==0.14.1
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.2/24.2 MB 83.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 887.5/887.5 MB 1.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 317.1/317.1 MB 3.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.0/21.0 MB 90.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 849.3/849.3 kB 48.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 557.1/557.1 MB 1.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: torch
#     Found existing installation: torch 2.5.1
#     Uninstalling torch-2.5.1:
#       Successfully uninstalled torch-2.5.1
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.20.1+cu121
#     Uninstalling torchvision-0.20.1+cu121:
#       Successfully uninstalled torchvision-0.20.1+cu121
# ...

# %%
pip install torchmetrics==0.6.0

# %%
pip install einops==0.8.0
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.2/43.2 kB 1.6 MB/s eta 0:00:00
# ...
#   Attempting uninstall: einops
#     Found existing installation: einops 0.3.0
#     Uninstalling einops-0.3.0:
#       Successfully uninstalled einops-0.3.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# stable-diffusion-sdkit 2.1.3 requires einops==0.3.0, but you have einops 0.8.0 which is incompatible.
# ...

# %%
pip install torch --upgrade
# Out:
# ...
#   Using cached torch-2.5.1-cp310-cp310-manylinux1_x86_64.whl.metadata (28 kB)
# ...
# Using cached torch-2.5.1-cp310-cp310-manylinux1_x86_64.whl (906.4 MB)
# ...
#   Attempting uninstall: torch
#     Found existing installation: torch 1.13.1
#     Uninstalling torch-1.13.1:
#       Successfully uninstalled torch-1.13.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# sentence-transformers 3.2.1 requires transformers<5.0.0,>=4.41.0, but you have transformers 4.26.1 which is incompatible.
# stable-diffusion-sdkit 2.1.3 requires einops==0.3.0, but you have einops 0.8.0 which is incompatible.
# torchvision 0.14.1 requires torch==1.13.1, but you have torch 2.5.1 which is incompatible.
# ...

# %%
pip install torchvision --upgrade
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.2/7.2 MB 38.5 MB/s eta 0:00:00
# ...
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.14.1
#     Uninstalling torchvision-0.14.1:
#       Successfully uninstalled torchvision-0.14.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# stable-diffusion-sdkit 2.1.3 requires einops==0.3.0, but you have einops 0.8.0 which is incompatible.
# ...

# %%
# !pip install torchtext==0.6.0  pytorch-lightning==1.2.2
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.2/64.2 kB 2.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 816.5/816.5 kB 15.9 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pytorch-lightning
#     Found existing installation: pytorch-lightning 1.4.2
#     Uninstalling pytorch-lightning-1.4.2:
#       Successfully uninstalled pytorch-lightning-1.4.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# stable-diffusion-sdkit 2.1.3 requires einops==0.3.0, but you have einops 0.8.0 which is incompatible.
# stable-diffusion-sdkit 2.1.3 requires pytorch-lightning==1.4.2, but you have pytorch-lightning 1.2.2 which is incompatible.
# ...

# %%
# !pip install diffusers==0.15.0
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 851.8/851.8 kB 13.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: diffusers
#     Found existing installation: diffusers 0.31.0
#     Uninstalling diffusers-0.31.0:
#       Successfully uninstalled diffusers-0.31.0
# ...

# %%
# !pip install jax==0.4.19
# !pip install jaxlib==0.4.19
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 14.4 MB/s eta 0:00:00
# ...
#   Attempting uninstall: jax
#     Found existing installation: jax 0.4.33
#     Uninstalling jax-0.4.33:
#       Successfully uninstalled jax-0.4.33
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# chex 0.1.87 requires jax>=0.4.27, but you have jax 0.4.19 which is incompatible.
# flax 0.8.5 requires jax>=0.4.27, but you have jax 0.4.19 which is incompatible.
# optax 0.2.4 requires jax>=0.4.27, but you have jax 0.4.19 which is incompatible.
# orbax-checkpoint 0.6.4 requires jax>=0.4.26, but you have jax 0.4.19 which is incompatible.
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.3/85.3 MB 26.5 MB/s eta 0:00:00
# ...
#   Attempting uninstall: jaxlib
#     Found existing installation: jaxlib 0.4.33
#     Uninstalling jaxlib-0.4.33:
#       Successfully uninstalled jaxlib-0.4.33
# ...

# %%
pip install pillow==9.1.0
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 37.5 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pillow
#     Found existing installation: pillow 11.0.0
#     Uninstalling pillow-11.0.0:
#       Successfully uninstalled pillow-11.0.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# sentence-transformers 3.2.1 requires transformers<5.0.0,>=4.41.0, but you have transformers 4.26.1 which is incompatible.
# ...

# %%
# remove line 29 from
# /usr/local/lib/python3.10/dist-packages/diffusers/utils/dynamic_modules_utils.py

# %%
cd src/SD_CLIP
# Out:
# /content/cleaned/src/geoaware_necessary_clone

# %%
#current
# !python pck_train_combined.py --config configs/train_sketch2.yaml
# Out:
# 2024-11-20 20:12:20.756972: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-11-20 20:12:20.774765: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-11-20 20:12:20.796288: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-11-20 20:12:20.802830: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...
